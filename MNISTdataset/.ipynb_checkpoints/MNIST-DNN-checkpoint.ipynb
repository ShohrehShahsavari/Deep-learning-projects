# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load data

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
# with np.load('mnist.npz') as data:
#     X_train = data['x_train']
#     y_train = data['y_train']
#     X_test = data['x_test']
#     y_test = data['y_test']

# %%
 X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize

# %%
fig, axes= plt.subplots(nrows=4 , ncols=6 , figsize=(9,6))
for item in zip(axes.ravel(), X_train, y_train):
    ax, image, target= item
    ax.imshow(image, cmap= 'gray_r')
    ax.set_title(f'Label: {target}')
    ax.axis('off')
plt.tight_layout()

# %% [markdown]
# # Classification with NN

# %%
imput_layer= keras.layers.Input(shape=(28,28))
flatten_layer= keras.layers.Flatten()(imput_layer)
hidden_layer1= keras.layers.Dense(128, activation= 'relu')(flatten_layer)
hidden_layer2= keras.layers.Dense(256, activation= 'relu')(hidden_layer1)
output_layer= keras.layers.Dense(10,activation= 'softmax')(hidden_layer2)

model=keras.Model(imput_layer, output_layer)
model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train,y_train)
print(model.summary())

test_loss, test_acc= model.evaluate(X_test,y_test)
print(f" test loss: {test_loss}")
print(f" test accuracy: {test_acc}")
# Out:
# 1875/1875 [==============================] - 4s 1ms/step - loss: 1.3253 - accuracy: 0.8598
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 136,074
# Trainable params: 136,074
# Non-trainable params: 0
# _________________________________________________________________
# None
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4354 - accuracy: 0.9140
#  test loss: 0.43538379669189453
#  test accuracy: 0.9139999747276306

# %%
imput_layer= keras.layers.Input(shape=(28,28))
flatten_layer= keras.layers.Flatten()(imput_layer)
hidden_layer1= keras.layers.Dense(128, activation= 'relu')(flatten_layer)
hidden_layer2= keras.layers.Dense(256, activation= 'relu')(hidden_layer1)
output_layer= keras.layers.Dense(10,activation= 'softmax')(hidden_layer2)

model=keras.Model(imput_layer, output_layer)
model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train,y_train, epochs=10, batch_size=32)
#print(model.summary())

test_loss, test_acc= model.evaluate(X_test,y_test)
print(f" test loss: {test_loss}")
print(f" test accuracy: {test_acc}")
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.5322 - accuracy: 0.8771
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3533 - accuracy: 0.9261
# Epoch 3/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2138 - accuracy: 0.9457
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1553 - accuracy: 0.9568
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1405 - accuracy: 0.9607
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1295 - accuracy: 0.9649
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1152 - accuracy: 0.9685
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1045 - accuracy: 0.9719
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0971 - accuracy: 0.9735
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0888 - accuracy: 0.9763
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1647 - accuracy: 0.9667
#  test loss: 0.16474168002605438
#  test accuracy: 0.96670001745224

# %% [markdown]
# # Implementing Batch Normalization with TensorFlow

# %%
input_layer = keras.layers.Input(shape= (28, 28))
flatten_layer = keras.layers.Flatten()(input_layer)

# First hidden block with BatchNorm
hidden_layer1 = keras.layers.Dense(128)(flatten_layer)  # No activation here
hidden_layer1 = keras.layers.BatchNormalization()(hidden_layer1)  # Add BatchNorm
hidden_layer1 = keras.layers.Activation('relu')(hidden_layer1)  # Activation AFTER BatchNorm

# Second hidden block with BatchNorm  
hidden_layer2 = keras.layers.Dense(256)(hidden_layer1)  # No activation here
hidden_layer2 = keras.layers.BatchNormalization()(hidden_layer2)  # Add BatchNorm
hidden_layer2 = keras.layers.Activation('relu')(hidden_layer2)  # Activation AFTER BatchNorm

output_layer = keras.layers.Dense(10, activation = 'softmax')(hidden_layer2)

model= keras.Model(input_layer, output_layer)
# optimizer= ['adam', 'rmsprop', 'sgd']
# Or from tensorflow.keras.optimizers import SGD
# optimizer = SGD(learning_rate=0.01, momentum=0.9)
# loss= ['mean_squared_error', 'mean_absolute_error', 'huber_loss', 'mean_squared_logarithmic_error'] regression
# loss= ['binary_crossentropy', 'sparse_categorical_crossentropy', 'categorical_crossentropy'] classification
# metrics=['mse', 'mse'] regression
### clasification metrics?
# Accuracy metrics
# metrics=['accuracy']  # Auto-detects binary/multi-class
# metrics=['binary_accuracy']  # For binary classification
# metrics=['categorical_accuracy']  # For one-hot encoded multi-class
# metrics=['sparse_categorical_accuracy']  # For integer labels multi-class
# metrics=['top_k_categorical_accuracy']  # Top-k accuracy
# metrics=['sparse_top_k_categorical_accuracy']  # Top-k with integer labels

# # Precision/Recall/F1
# metrics=['precision']  # For binary
# metrics=['recall']  # For binary  
# metrics=['auc']  # Area Under ROC Curve
# metrics=['prc'] or metrics=['precision_at_recall']  # Precision-Recall Curve

model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs= 10, batch_size= 32, validation_data = (X_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2099 - sparse_categorical_accuracy: 0.9360 - val_loss: 1.5476 - val_sparse_categorical_accuracy: 0.6202
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9679 - val_loss: 0.2558 - val_sparse_categorical_accuracy: 0.9261
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.4846 - val_sparse_categorical_accuracy: 0.8590
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0609 - sparse_categorical_accuracy: 0.9799 - val_loss: 1.5067 - val_sparse_categorical_accuracy: 0.6928
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.3095 - val_sparse_categorical_accuracy: 0.9142
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.1312 - val_sparse_categorical_accuracy: 0.9621
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.2045 - val_sparse_categorical_accuracy: 0.9469
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0345 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.1847 - val_sparse_categorical_accuracy: 0.9483
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.1383 - val_sparse_categorical_accuracy: 0.9639
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.1899 - val_sparse_categorical_accuracy: 0.9539

# %% [markdown]
# # ℓ1 and ℓ2 Regularization

# %%
l1_reg = 0.001
l2_reg = 0.01

input_layer = keras.layers.Input(shape= (28, 28))
flatten_layer = keras.layers.Flatten()(input_layer)

# First hidden block
hidden_layer1 = keras.layers.Dense(128, kernel_regularizer= keras.regularizers.l1_l2(l1= l1_reg, l2= l2_reg), bias_regularizer= keras.regularizers.l2(l2_reg))(flatten_layer)
hidden_layer1 = keras.layers.BatchNormalization()(hidden_layer1)
hidden_layer1 = keras.layers.Activation('relu')(hidden_layer1)

# Second hidden block 
hidden_layer2 = keras.layers.Dense(256, kernel_regularizer= keras.regularizers.l1_l2(l1= l1_reg, l2= l2_reg), bias_regularizer= keras.regularizers.l2(l2_reg))(hidden_layer1)  # No activation here
hidden_layer2 = keras.layers.BatchNormalization()(hidden_layer2)  # Add BatchNorm
hidden_layer2 = keras.layers.Activation('relu')(hidden_layer2)  # Activation AFTER BatchNorm

output_layer = keras.layers.Dense(10, activation = 'softmax')(hidden_layer2)

model= keras.Model(input_layer, output_layer)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss= 'sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs= 10, batch_size= 32, validation_data = (X_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 19s 8ms/step - loss: 1.5424 - sparse_categorical_accuracy: 0.8964 - val_loss: 0.8586 - val_sparse_categorical_accuracy: 0.9112
# Epoch 2/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.7770 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.6403 - val_sparse_categorical_accuracy: 0.9380
# Epoch 3/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.6209 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.5342 - val_sparse_categorical_accuracy: 0.9405
# Epoch 4/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5570 - sparse_categorical_accuracy: 0.9320 - val_loss: 0.4810 - val_sparse_categorical_accuracy: 0.9517
# Epoch 5/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4623 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.4102 - val_sparse_categorical_accuracy: 0.9567

# %% [markdown]
# # Dropout

# %%
input_layer = keras.layers.Input(shape=(28, 28))
flatten_layer = keras.layers.Flatten()(input_layer)

hidden_layer1 = keras.layers.Dense(128)(flatten_layer)
hidden_layer1 = keras.layers.BatchNormalization()(hidden_layer1)
hidden_layer1 = keras.layers.Activation('relu')(hidden_layer1)
hidden_layer1 = keras.layers.Dropout(rate = 0.3)(hidden_layer1)

hidden_layer2 = keras.layers.Dense(256)(hidden_layer1)
hidden_layer2 = keras.layers.BatchNormalization()(hidden_layer2)
hidden_layer2 = keras.layers.Activation('relu')(hidden_layer2)
hidden_layer2 = keras.layers.Dropout(rate=0.3)(hidden_layer2)

output_layer = keras.layers.Dense(10, activation= 'softmax')(hidden_layer2)

dnn_model = keras.Model(input_layer, output_layer)
dnn_model.compile(optimizer= keras.optimizers.Adam(), loss = 'sparse_categorical_crossentropy', metrics= 'sparse_categorical_accuracy')
dnn_model.fit(X_train, y_train, epochs=10, batch_size= 32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 19s 8ms/step - loss: 0.3542 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.1284 - val_sparse_categorical_accuracy: 0.9597
# Epoch 2/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2055 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9704
# Epoch 3/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1690 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9728
# Epoch 4/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1542 - sparse_categorical_accuracy: 0.9522 - val_loss: 0.0784 - val_sparse_categorical_accuracy: 0.9770
# Epoch 5/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1353 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.0701 - val_sparse_categorical_accuracy: 0.9788
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1294 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.0747 - val_sparse_categorical_accuracy: 0.9771
# Epoch 7/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.0675 - val_sparse_categorical_accuracy: 0.9811
# Epoch 8/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1143 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0640 - val_sparse_categorical_accuracy: 0.9805
# Epoch 9/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1081 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.0610 - val_sparse_categorical_accuracy: 0.9820
# Epoch 10/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1040 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.0602 - val_sparse_categorical_accuracy: 0.9818

# %%
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import layers

layer1 = keras.layers.Dense(300, activation= 'relu', input_shape= (X_train.shape[1],))
layer2 = keras.layers.Dense(100, activation= 'relu')
layer3 = keras.layers.Dense(10, activation= 'softmax')
dnn_model = keras.Sequential([layer1, layer2, layer3])
dnn_model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'])
history = dnn_model.fit(X_train, y_train, batch_size=5, epochs= 5, validation_data= (X_test, y_test)) # epochs= 40000 // (len(X_train) // 50)
test_loss, test_accuracy = dnn_model.evaluate(X_test, y_test)
y_pred = dnn_model.predict(X_test)
y_pred_classes = tf.argmax(y_pred, axis=1)
# Out:
# Epoch 1/5
# 11200/11200 [==============================] - 72s 6ms/step - loss: 0.1972 - accuracy: 0.9414 - val_loss: 0.1305 - val_accuracy: 0.9624
# Epoch 2/5
# 11200/11200 [==============================] - 70s 6ms/step - loss: 0.0951 - accuracy: 0.9709 - val_loss: 0.0977 - val_accuracy: 0.9707
# Epoch 3/5
# 11200/11200 [==============================] - 81s 7ms/step - loss: 0.0734 - accuracy: 0.9779 - val_loss: 0.1102 - val_accuracy: 0.9718
# Epoch 4/5
# 10705/11200 [===========================>..] - ETA: 2s - loss: 0.0616 - accuracy: 0.9818
